# %%
# Exercise 01.1

T_f = 46
T_c = 5 * (T_f - 32) / 9

print(T_c)
# Out:
# 7.777777777777778

# %%
# Exercise 01.2

principal = 172000
boe_rate = 2.25
extra_rate = 1.49

rate = (boe_rate + extra_rate) / 100
annual_interest = principal * rate
interest = annual_interest / 12

print(interest)
# Out:
# 536.0666666666667
